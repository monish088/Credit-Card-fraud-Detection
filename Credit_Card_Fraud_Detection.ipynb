# %% [markdown]
# Importing the Dependencies

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
# loading the dataset to Pandas DataFrame
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
#first five rows of the dataset
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
#         V26       V27       V28  Amount  Class
# 0 -0.189115  0.133558 -0.021053  149.62    0.0
# 1  0.125895 -0.008983  0.014724    2.69    0.0
# 2 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3 -0.221929  0.062723  0.061458  123.50    0.0
# 4  0.502292  0.219422  0.215153   69.99    0.0
#
# [5 rows x 31 columns]

# %%
# dataset information
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59511 entries, 0 to 59510
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    59511 non-null  int64
#  1   V1      59511 non-null  float64
#  2   V2      59511 non-null  float64
#  3   V3      59511 non-null  float64
#  4   V4      59511 non-null  float64
#  5   V5      59511 non-null  float64
#  6   V6      59511 non-null  float64
#  7   V7      59511 non-null  float64
#  8   V8      59511 non-null  float64
#  9   V9      59511 non-null  float64
#  10  V10     59511 non-null  float64
#  11  V11     59511 non-null  float64
#  12  V12     59511 non-null  float64
#  13  V13     59511 non-null  float64
#  14  V14     59511 non-null  float64
#  15  V15     59511 non-null  float64
#  16  V16     59510 non-null  float64
#  17  V17     59510 non-null  float64
#  18  V18     59510 non-null  float64
#  19  V19     59510 non-null  float64
#  20  V20     59510 non-null  float64
#  21  V21     59510 non-null  float64
#  22  V22     59510 non-null  float64
#  23  V23     59510 non-null  float64
#  24  V24     59510 non-null  float64
#  25  V25     59510 non-null  float64
#  26  V26     59510 non-null  float64
#  27  V27     59510 non-null  float64
#  28  V28     59510 non-null  float64
#  29  Amount  59510 non-null  float64
#  30  Class   59510 non-null  float64
# dtypes: float64(30), int64(1)
# memory usage: 14.1 MB

# %%
# checking the number of missing values in each coloumn
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
# distribution of legit transaction and fraudlent transactions
credit_card_data['Class'].value_counts()
# Out:
# 0.0    59348
# 1.0      162
# Name: Class, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced

# %% [markdown]
# 0 ----> normal transactions
#
# 1 --> fraudlent transactions

# %%
# separating the data for analysis
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (59348, 31)
# (162, 31)

# %%
#statistical measures of data
legit.Amount.describe()
# Out:
# count    59348.000000
# mean        95.423013
# std        270.229826
# min          0.000000
# 25%          7.690000
# 50%         25.985000
# 75%         87.440000
# max      19656.530000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count     162.000000
# mean       93.565988
# std       224.658775
# min         0.000000
# 25%         1.000000
# 50%         4.245000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
#compare the values for both transactions
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0.0    31756.653956 -0.220094 -0.024129  0.716642  0.156674 -0.246262
# 1.0    28583.783951 -7.086497  5.090192 -9.571784  5.554124 -5.230160
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.108918 -0.094662  0.045945  0.072867  ...  0.047016 -0.030245
# 1.0   -2.157161 -7.462325  3.433510 -3.352556  ...  0.424429  0.851337
#
#            V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.10724 -0.039144  0.006999  0.135867  0.019860  0.001431  0.004203
# 1.0   -0.20449 -0.262548 -0.080078  0.238594  0.124826  0.566296  0.036929
#
#           Amount
# Class
# 0.0    95.423013
# 1.0    93.565988
#
# [2 rows x 30 columns]

# %% [markdown]
# Under - Sampling

# %% [markdown]
# Build a sample dataset containing similar distribution of normal transactions and fradulent transactions

# %%
legit_sample = legit.sample(n = 162)

# %% [markdown]
# Conacatenating two DataFrames

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 43755  41641  1.428597 -0.907639 -0.058047 -1.370968 -1.000969 -0.820064
# 34953  37894  0.442845  1.492794 -1.605712  1.625162  1.352480 -1.869859
# 58549  48440  1.314607 -0.184961  0.120973 -0.463546 -0.768848 -1.214965
# 52813  45656 -1.171559  1.745159  1.441715 -0.047893 -0.300120 -0.571349
# 35491  38143 -0.273273  1.224363  0.975346 -0.151459  0.564503 -0.469740
#
#              V7        V8        V9  ...       V21       V22       V23  \
#
# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 43755  41641  1.428597 -0.907639 -0.058047 -1.370968 -1.000969 -0.820064
# 34953  37894  0.442845  1.492794 -1.605712  1.625162  1.352480 -1.869859
# 58549  48440  1.314607 -0.184961  0.120973 -0.463546 -0.768848 -1.214965
# 52813  45656 -1.171559  1.745159  1.441715 -0.047893 -0.300120 -0.571349
# 35491  38143 -0.273273  1.224363  0.975346 -0.151459  0.564503 -0.469740
# ...      ...       ...       ...       ...       ...       ...       ...
# 57248  47826 -0.887287  1.390002  1.219686  1.661425  1.009228 -0.733908
# 57470  47923  0.364377  1.443523 -2.220907  2.036985 -1.237055 -1.728161
# 57615  47982 -1.232804  2.244119 -1.703826  1.492536 -1.192985 -1.686110
# 58422  48380 -2.790771 -1.464269  1.031165  1.921356 -0.090014 -0.483871
# 58761  48533  1.243848  0.524526 -0.538884  1.209196  0.479538 -0.197429
#
#              V7        V8        V9  ...       V20       V21       V22  \
# 43755 -0.473898 -0.275356 -2.253413  ... -0.268286 -0.450328 -0.991395
# 34953  1.326924 -0.861025  0.126721  ...  0.092886 -0.239459 -0.062221
# 58549 -0.256690 -0.190032 -1.080099  ...  0.065962 -0.271235 -0.912385
# 52813 -0.029771 -2.498441 -0.393213  ... -0.328226  2.098413 -1.220703
# 35491  0.786911 -0.099961 -0.552009  ...  0.225427 -0.304431 -0.727040
# ...         ...       ...       ...  ...       ...       ...       ...
# 57248  0.855829  0.000077 -1.275631  ... -0.268347 -0.083734 -0.346930
# 57470 -2.058582  0.358895 -1.393306  ...  0.310980  0.402730 -0.132129
# 57615 -1.864612  0.856122 -1.973535  ...  0.207889  0.560475  0.165682
# 58422  0.780731 -0.348776  0.609133  ... -1.376721 -0.392667  0.440020
# 58761  0.049166  0.037792  0.128119  ... -0.171541 -0.051660 -0.084089
#
#             V23       V24       V25       V26       V27       V28  Amount
# 43755  0.143926  0.038056  0.266546 -0.425621  0.014823  0.019815   52.96
# 34953  0.204475  0.046044 -0.485114 -0.485301 -0.415024 -0.468926    0.89
# 58549  0.281809  0.476955  0.056322 -0.644520  0.020190  0.043905   20.00
# 52813  0.347408  0.680678 -0.140620  0.065747  0.376654  0.150813    2.69
# 35491 -0.142015 -0.467661 -0.001782  0.119243  0.254813  0.092547    0.99
# ...         ...       ...       ...       ...       ...       ...     ...
# 57248 -0.050619  0.231044 -0.450760 -0.376205  0.034504  0.157775    7.58
# 57470 -0.032977  0.460861  0.560404  0.409366  0.539668  0.296918    0.76
# 57615 -0.013754  0.474935 -0.218725  0.302809  0.466031  0.250134    0.76
# 58422  0.777659  0.418552  0.244563 -0.159361  0.060540  0.356958  208.58
# 58761 -0.192846 -0.917392  0.681953 -0.194419  0.045917  0.040136    1.00
#
# [324 rows x 30 columns]

# %%
print(Y)
# Out:
# 43755    0.0
# 34953    0.0
# 58549    0.0
# 52813    0.0
# 35491    0.0
#         ...
# 57248    1.0
# 57470    1.0
# 57615    1.0
# 58422    1.0
# 58761    1.0
# Name: Class, Length: 324, dtype: float64

# %% [markdown]
# Split the data into training data and testing data

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2, stratify=Y,random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (324, 30) (259, 30) (65, 30)

# %% [markdown]
# Model Training

# %%
model = LogisticRegression()

# %%
# training the model with training data
model.fit(X_train, Y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# Model Evaluation

# %%
# accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('Accuracy on training data:', training_data_accuracy)
# Out:
# Accuracy on training data: 0.9498069498069498

# %%
# accuracy on test data
X_test_prediction = model.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('Accuracy Score on test Data : ', test_data_accuracy)
# Out:
# Accuracy Score on test Data :  0.9230769230769231
